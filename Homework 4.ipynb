# %% [markdown]
# # Homework 4 - SQL Fundamentals

# %% [markdown]
# 1.  https://leetcode.com/problems/actors-and-directors-who-cooperated-at-least-three-times/submissions/1849758355/

# %% [markdown]
# PANDAS ![image.png](attachment:dee8e5de-b3c3-4ec4-92a4-48c125466ddd.png)

# %% [markdown]
# SQL
# ![image.png](attachment:b33762af-81de-469d-99bf-d4d2e07cecd9.png)

# %% [markdown]
# 2. https://leetcode.com/problems/fix-names-in-a-table/

# %% [markdown]
# PANDAS
# ![image.png](attachment:5d2b8f98-2515-406f-905f-0c1fed7a55a9.png)

# %% [markdown]
# SQL
# ![image.png](attachment:7ad81d95-98ca-45e2-ad04-b6864e7e42b9.png)

# %% [markdown]
# 3. https://leetcode.com/problems/combine-two-tables/description/

# %% [markdown]
# PANDAS
# ![image.png](attachment:3753d78c-24f0-467d-8184-c2dd74a3acf4.png)

# %% [markdown]
# SQL
# ![image.png](attachment:123b8316-39a8-466d-b9a0-35ebdce26a81.png)

# %% [markdown]
# 4. https://leetcode.com/problems/second-highest-salary/description/

# %% [markdown]
# PANDAS
# ![image.png](attachment:2a2485ea-e478-4dab-a60f-b9ce07588035.png)

# %% [markdown]
# SQL
# ![image.png](attachment:092d993d-7d31-4d29-b214-584090883e24.png)

# %% [markdown]
# 5. https://leetcode.com/problems/list-the-products-ordered-in-a-period/

# %% [markdown]
# PANDAS
# ![image.png](attachment:8822171e-11c7-41fa-a84f-2b11f9704c39.png)

# %% [markdown]
# SQL
# ![image.png](attachment:f780df2f-15f9-497c-a39d-cd502c7186ba.png)

# %% [markdown]
# 6. https://leetcode.com/problems/replace-employee-id-with-the-unique-identifier/

# %% [markdown]
# PANDAS
# ![image.png](attachment:01e9e373-fe8e-44db-9f1b-41d927de52e2.png)

# %% [markdown]
# SQL
# ![image.png](attachment:a93e8c07-12b1-49a1-adc7-5df49121a586.png)

# %% [markdown]
# 7. https://leetcode.com/problems/game-play-analysis-iv/

# %% [markdown]
# PANDAS
# ![image.png](attachment:51c0f93e-18f0-464c-9968-30dd9a37a2df.png)

# %% [markdown]
# SQL
# ![image.png](attachment:42cee8ee-655f-45ec-a740-351808a71c8b.png)

# %% [markdown]
# 8. https://leetcode.com/problems/project-employees-i/

# %% [markdown]
# PANDAS
# ![image.png](attachment:a9ff92bc-8569-4428-b156-a299824a3ea7.png)

# %% [markdown]
# SQL
# ![image.png](attachment:8af25549-44cf-4ca9-b262-1bc8ea89a506.png)

# %% [markdown]
# 9. https://leetcode.com/problems/department-top-three-salaries/

# %% [markdown]
# PANDAS
